# %%
# %pylab
a = array([1,2,3,4])
b = array([2,3,4,5])
a * b
# Out:
# array([ 2,  6, 12, 20])

# %%
a = linspace(0, 2*pi, 21)
# %precision 3
b = sin(a)
# %matplotlib inline
plot(a,b)

# %%
a = linspace(0, 2*pi, 21)
# %precision 3
b = sin(a)
# %matplotlib inline
b >= 0
mask = b >= 0
plot(a[mask], b[mask], 'ro')
